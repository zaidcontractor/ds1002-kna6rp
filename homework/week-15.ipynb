# %% [markdown]
# <a href="https://colab.research.google.com/github/zaidcontractor/ds1002-kna6rp/blob/main/homework/week-15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework - Week 15
#
# Complete the following blocks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL to your notebook for review.

# %% [markdown]
# ## 1. Create Functions (4 pts)
#
# Create two functions in the cells below, according to the prompts given.

# %%
# create a function in R that:
#   1. takes a single integer as an input parameter
#   2. determines whether the integer is even or odd
#   3. returns a character statement "The integer <x> is even" or "The integer <x> is odd" (replace <x> with the actual input provided)
#
# then execute the function twice using two different input values, displaying even and odd results.

odd_even <- function(var1) {
  if ((var1 %% 2) == 0) {
    print(sprintf("The integer %i is even",var1))
  }
  else {
    print(sprintf("The integer %i is odd",var1))
  }
}

odd_even(54)
odd_even(77)
# Out:
# [1] "The integer 54 is even"
# [1] "The integer 77 is odd"

# %%
# create a function in R that:
#   1. takes 4 integer input parameters
#   2. returns the mean value of the inputs
#   3. has default values for the 4 input parameters, in case they are not provided when the function is called.
#
# then execute the function twice: once where you provide the input values, and once where you do not.

mean_value <- function(var1 = 2, var2 = 4, var3 = 6, var4 = 8){
  total = var1 + var2 + var3 + var4
  mean = total/4
  return(mean)
}

mean_value(1,5,8,20)
mean_value()
# Out:
# [1] 8.5
# [1] 5

# %% [markdown]
# ## 2. Plot Data (4 pts)

# %% [markdown]
# In the cell below, write the code required to plot from the `msleep` sample data set.
#
# 1. Display only animals with body weights of 30 or greater.
# 2. Group the animals by `order`.
# 3. Display the mean `sleep_total` for each group in a bar plot.

# %%
install.packages('ggplot2')
library(ggplot2)
data(msleep)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
msleep
# Out:
#    name                           genus         vore    order
# 1  Cheetah                        Acinonyx      carni   Carnivora
# 2  Owl monkey                     Aotus         omni    Primates
# 3  Mountain beaver                Aplodontia    herbi   Rodentia
# 4  Greater short-tailed shrew     Blarina       omni    Soricomorpha
# 5  Cow                            Bos           herbi   Artiodactyla
# 6  Three-toed sloth               Bradypus      herbi   Pilosa
# 7  Northern fur seal              Callorhinus   carni   Carnivora
# 8  Vesper mouse                   Calomys       NA      Rodentia
# 9  Dog                            Canis         carni   Carnivora
# 10 Roe deer                       Capreolus     herbi   Artiodactyla
# 11 Goat                           Capri         herbi   Artiodactyla
# 12 Guinea pig                     Cavis         herbi   Rodentia
# 13 Grivet                         Cercopithecus omni    Primates
# ...

# %%
install.packages("tidyverse")
library(tidyverse)

df <- msleep %>%
  group_by(order) %>%
  filter(bodywt > 30) %>%
  summarize(mean_sleep_total = mean(sleep_total))

df
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#   order          mean_sleep_total
# 1 Artiodactyla    4.820000
# 2 Carnivora      10.250000
# 3 Cetacea         4.500000
# 4 Cingulata      18.100000
# 5 Perissodactyla  3.466667
# 6 Primates        8.850000
# 7 Proboscidea     3.600000

# %%
ggplot(df, aes(x=order, y=mean_sleep_total)) +
  geom_bar(stat = "identity")
# Out:
# plot without title

# %% [markdown]
# ## 3. Clean and Analyze Data Using R (4 pts)
#
# In the cells below use R to perform the following data cleaning steps on this file:
# https://raw.githubusercontent.com/nmagee/ds1002/main/data/social-media-users.csv
#
# 1. Remove any duplicate rows.
# 2. Remove any records where `last_login` or `birthdate` are empty.
# 3. Display only the records with the 10 highest `follower` counts.
# 4. Determine counts of users when grouped by continent.

# %%
df <- read.csv("https://raw.githubusercontent.com/nmagee/ds1002/main/data/social-media-users.csv")
head(df)
# Out:
#   username    full_name        birthdate  email                  continent
# 1 ckippen0    Clevey Kippen    5/1/1991   ckippen0@t-online.de   NA
# 2 tgergler1   Tedi Gergler     10/5/1998  tgergler1@salon.com    NA
# 3 spomfrett2  Steffie Pomfrett            spomfrett2@imdb.com    NA
# 4 rphettis3   Ruddy Phettis    6/18/1984  rphettis3@npr.org      EU
# 5 ngilcriest4 Nico Gilcriest   10/11/1993 ngilcriest4@dyndns.org NA
# 6 fhampson5   Farrell Hampson  11/7/1985  fhampson5@lulu.com     OC
#   followers last_login interests
# 1 12362     5/16/2023  music
# 2 21360     8/20/2020  sports
# 3 19530     11/19/2022 sports
# 4 80047     9/20/2023  travel
# 5 33544                music
# 6 72161                sports

# %%
nrow(df[duplicated(df), ])
# Out:
# [1] 318

# %%
df <- df[!duplicated(df), ]
df
# Out:
#      username       full_name            birthdate
# 1    ckippen0       Clevey Kippen        5/1/1991
# 2    tgergler1      Tedi Gergler         10/5/1998
# 3    spomfrett2     Steffie Pomfrett
# 4    rphettis3      Ruddy Phettis        6/18/1984
# 5    ngilcriest4    Nico Gilcriest       10/11/1993
# 6    fhampson5      Farrell Hampson      11/7/1985
# 7    ttotman6       Tamqrah Totman       8/7/1986
# 8    bdennes7       Bonita Dennes
# 9    kgrigoryev8    Krishna Grigoryev    5/25/1990
# 10   mbathoe9       Mallissa Bathoe
# 11   hallensona     Hayward Allenson     3/15/1983
# 12   mchittockb     Myriam Chittock      1/26/1989
# 13   mfranzewitchc  Max Franzewitch      12/25/1997
# 14   aeasbyd        Alessandra Easby     1/5/1991
# 15   hschubarte     Hubert Schubart      11/23/1984
# 16   dleishmanf     Dyane Leishman       2/12/1990
# 17   scoilsg        Shayla Coils
# 18   bkrzysztofh    Bendick Krzysztof    10/19/1985
# 19   omarusiki      Otha Marusik         12/4/1992
# ...

# %%
df[df==""] <- NA

df <- df[complete.cases(df$birthdate), ]
df <- df[complete.cases(df$last_login), ]
df
# Out:
#     username       full_name            birthdate
# 1   vmacterrellyrm Virginie MacTerrelly 10/8/1994
# 2   lcolviemr      Lana Colvie          1/10/1990
# 3   mdavitt8a      Mychal Davitt        4/29/1982
# 4   kyoellgl       Karine Yoell         6/14/1994
# 5   gfassumfg      Garry Fassum         5/21/1995
# 6   tfolkc7        Tanney Folk          12/26/2000
# 7   dmapledorumcs  Dyann Mapledorum     5/15/1993
# 8   mmoffatthx     Malanie Moffatt      10/25/1981
# 9   mzanollipf     Marlene Zanolli      9/17/1981
# 10  dtresvina6x    Dion Tresvina        12/28/1993
# 11  gheball88      Gaven Heball         12/16/2002
# 12  awisdeneu      Allis Wisden         3/28/1998
# 13  mdurbin2i      Maridel Durbin       4/14/1990
# 14  cferroli1r     Cullin Ferroli       2/9/1998
# 15  plendremkh     Patten Lendrem       5/19/2000
# 16  cjentzschg9    Cecilia Jentzsch     6/27/1992
# 17  wmilesnt       Wilona Miles         7/8/1993
# 18  gsandercockp9  Gloriane Sandercock  6/23/2002
# ...

# %%
df <- df[order(-df$followers),]
df
# Out:
#     username       full_name            birthdate
# 650 lleckeyb6      Lynne Leckey         4/19/1998
# 649 spharoaha2     Staci Pharoah        9/2/1985
# 648 cduftondy      Celisse Dufton       8/24/1995
# 647 dbartalin77    Desiree Bartalin     8/23/1993
# 646 grivardmp      Gwen Rivard          9/12/1982
# 645 mraggitt9g     Morgan Raggitt       11/16/1992
# 644 wbenese7       Wain Benes           3/9/1998
# 643 kmorriceht     Kitti Morrice        6/3/1995
# 642 smacdonnell7o  Shoshanna MacDonnell 9/12/2002
# 641 dcossum34      Dwain Cossum         9/9/1990
# 640 gbluneqj       Gusta Blune          11/25/1997
# 639 ebroomq9       Early Broom          3/10/2000
# 638 sgoublierfo    Salomon Goublier     10/30/1994
# 637 schapell4j     Shepard Chapell      9/3/1993
# 636 tbaptiepo      Thorvald Baptie      10/23/1981
# 635 nbarbeyq2      Nelson Barbey        12/15/1984
# 634 jhovendene3    Jandy Hovenden       11/6/1992
# 633 vlangtree7w    Valina Langtree      1/16/1984
# ...

# %%
head(df,n=10)
# Out:
#     username      full_name            birthdate  email
# 650 lleckeyb6     Lynne Leckey         4/19/1998  lleckeyb6@tripadvisor.com
# 649 spharoaha2    Staci Pharoah        9/2/1985   spharoaha2@sfgate.com
# 648 cduftondy     Celisse Dufton       8/24/1995  cduftondy@ox.ac.uk
# 647 dbartalin77   Desiree Bartalin     8/23/1993  dbartalin77@usda.gov
# 646 grivardmp     Gwen Rivard          9/12/1982  grivardmp@google.com.hk
# 645 mraggitt9g    Morgan Raggitt       11/16/1992 mraggitt9g@home.pl
# 644 wbenese7      Wain Benes           3/9/1998   wbenese7@ebay.com
# 643 kmorriceht    Kitti Morrice        6/3/1995   kmorriceht@privacy.gov.au
# 642 smacdonnell7o Shoshanna MacDonnell 9/12/2002  smacdonnell7o@toplist.cz
# 641 dcossum34     Dwain Cossum         9/9/1990   dcossum34@dagondesign.com
#     continent followers last_login interests
# 650 SA        99977     3/14/2021  sports
# 649 NA        99905     10/26/2023 sports
# 648 OC        99707     9/26/2021  sports
# ...

# %%
#https://stackoverflow.com/questions/25293045/count-number-of-rows-in-a-data-frame-in-r-based-on-group

df %>%
  group_by(continent) %>%
  summarize(count=n())
# Out:
#   continent count
# 1 AF         70
# 2 AS        111
# 3 EU         77
# 4 OC         95
# 5 SA         69
# 6 NA        228

# %% [markdown]
# <a href="https://colab.research.google.com/github/zaidcontractor/ds1002-kna6rp/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt
plt.pie(slices, labels=labels)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
import seaborn as sns
sns.histplot(n)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
#df = pd.DataFrame({'x': x, 'y': y})

# %%
# Scatter plot without a trendline
plt.scatter(x,y)

# %%
# Scatter plot with the trendline

# Let z be a new calculation of a quadratic trendline for our data
z = np.polyfit(x, y, 2)

# Then p will be a plot of that line
p = np.poly1d(z)

# Combine the two!
plt.plot(x, p(x))
plt.scatter(x,y)
